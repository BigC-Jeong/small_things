# %% [markdown]
# <a href="https://colab.research.google.com/github/BigC-Jeong/small_things/blob/main/age_level_calculate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 프로그램명: age level calculating Program.py
# 작성자: 심리학과 정창민
# 작성일: 03272025
# 설명: 나이별 연령대 판단 프로그램

# %%
name = input("이름을 입력하세요: ")
age = int(input("나이를 입력하세요: "))

if age < 20 :
  print(name, "님은 청소년입니다.")
elif age < 30 :
  print(name, "님은 20대입니다.")
elif age < 40 :
  print(name, "님은 30대입니다.")
elif age < 50 :
  print(name, "님은 40대입니다.")
elif age < 60 :
  print(name, "님은 50대입니다.")
else :
  print(name, "님은 60대 이상입니다.")
# Out:
# 이름을 입력하세요:  홍길동
# 나이를 입력하세요: 36
#  홍길동 님은 30대입니다.
